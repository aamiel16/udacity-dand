# %% [markdown]
# # Analyzing NYC Subway Data using Pandas

# %% [markdown]
# ### Imports and Settings

# %%
% matplotlib inline

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import plotly.plotly as py

# %%
# Figure names
fig_prefix = '../figures/2015-09-15-as-subway-pd-lab-'

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# #### Importing the CSV

# %%
subway_df = pd.read_csv('../data/nyc_subway_weather.csv')

# %% [markdown]
# #### Some information about the data

# %%
# Displays the first 5 rows
subway_df.head()
# Out:
#    UNIT     DATEn     TIMEn  ENTRIESn   EXITSn  ENTRIESn_hourly  \
# 0  R003  05-01-11  00:00:00   4388333  2911002              0.0
# 1  R003  05-01-11  04:00:00   4388333  2911002              0.0
# 2  R003  05-01-11  12:00:00   4388333  2911002              0.0
# 3  R003  05-01-11  16:00:00   4388333  2911002              0.0
# 4  R003  05-01-11  20:00:00   4388333  2911002              0.0
#
#    EXITSn_hourly             datetime  hour  day_week     ...       pressurei  \
# 0            0.0  2011-05-01 00:00:00     0         6     ...           30.22
# 1            0.0  2011-05-01 04:00:00     4         6     ...           30.25
# 2            0.0  2011-05-01 12:00:00    12         6     ...           30.28
# 3            0.0  2011-05-01 16:00:00    16         6     ...           30.26
# 4            0.0  2011-05-01 20:00:00    20         6     ...           30.28
#
#   rain  tempi  wspdi meanprecipi  meanpressurei  meantempi  meanwspdi  \
# ...

# %%
# Information about the data
subway_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42649 entries, 0 to 42648
# Data columns (total 27 columns):
# UNIT               42649 non-null object
# DATEn              42649 non-null object
# TIMEn              42649 non-null object
# ENTRIESn           42649 non-null int64
# EXITSn             42649 non-null int64
# ENTRIESn_hourly    42649 non-null float64
# EXITSn_hourly      42649 non-null float64
# datetime           42649 non-null object
# hour               42649 non-null int64
# day_week           42649 non-null int64
# weekday            42649 non-null int64
# station            42649 non-null object
# latitude           42649 non-null float64
# longitude          42649 non-null float64
# conds              42649 non-null object
# fog                42649 non-null int64
# precipi            42649 non-null float64
# pressurei          42649 non-null float64
# rain               42649 non-null int64
# tempi              42649 non-null float64
# ...

# %% [markdown]
# ## Data Editing

# %%
# Converting the day in data to string dates
days_list = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
def convert_days(day):
    return days_list[day]   
       
subway_df['day_week'] = subway_df['day_week'].apply(convert_days)
subway_df['day_week'] = pd.Categorical(subway_df['day_week'], days_list)

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### Looking into variables' correlation

# %%
def standardize(x):
    '''
    Returns a standardize/normalize dataframe of x
    
    Function argument:
    x -- a dataframe with 1 column
    '''
    standardized = (x - x.mean())/x.std(ddof=0)
    
    return standardized

def correlation(x, y):
    '''
    Returns the Pearson's R for variables x and y
    correlation = average of (x in standard units) times (y in standard units)
    '''
    std_x = standardize(x)
    std_y = standardize(y)
    prsn_r = (std_x*std_y).mean()
    
    return prsn_r

# %%
# Variable Data
entries = subway_df['ENTRIESn_hourly']
cum_entries = subway_df['ENTRIESn']
rain = subway_df['meanprecipi']
temp = subway_df['meantempi']

# %% [markdown]
# #### Correlation between variables

# %%
print 'entries and rain: %f' % correlation(entries, rain)
print 'entries and temperature: %f' % correlation(entries, temp)
print 'rain and temperature: %f' % correlation(rain, temp)
print 'hourly entries and cumulative entries: %f' % correlation(entries, cum_entries)
# Out:
# entries and rain: 0.035649
# entries and temperature: -0.026693
# rain and temperature: -0.229034
# hourly entries and cumulative entries: 0.585895

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Cumulative Entries by Location

# %%
grouped_by_loc = subway_df.groupby(['latitude', 'longitude'], as_index=False).mean()
lati = grouped_by_loc['latitude']
longi = grouped_by_loc['longitude']
bubble_size = (grouped_by_loc['ENTRIESn']-grouped_by_loc['ENTRIESn'].mean())/grouped_by_loc['ENTRIESn'].std()

# %%
# Plot
plt.figure(figsize=(14,7))
plt.scatter(x=lati,y=longi,s=bubble_size*500, c=bubble_size, alpha=.5, cmap='Accent')
plt.colorbar()

# Plot Properties
plt.gca().invert_yaxis()
plt.title('Cumulative Entries by Location')
plt.xlabel('Latitude')
plt.ylabel('Longitude')

plt.savefig(fig_prefix+'cum_entries_by_loc')

# %% [markdown]
# #### Hourly Entries and Exits When Raining or Not

# %% [markdown]
# #### Hourly Entries Per Day of Week

# %%
grouped_entries_by_day = subway_df.groupby(['day_week', 'rain']).mean()['ENTRIESn_hourly']

# %%
plt.figure()
p = grouped_entries_by_day.ix[:,0].plot(kind='bar', label='With rain', alpha=0.75, color='b')
p = grouped_entries_by_day.ix[:,1].plot(kind='bar', label='Without rain', alpha=0.55, color='g')
p.xaxis.set_ticks_position('none')
p.set_xticklabels(days_list)
p.set_xlabel('Days')
p.set_ylabel('Mean Hourly Entries')
p.set_title('Mean Hourly Entries by Day')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## Data Visualization with Seaborn

# %% [markdown]
# #### Correlation between Hourly Entries and Cumulative Entries

# %%
entries_df = subway_df[['ENTRIESn', 'ENTRIESn_hourly']]
jg = sns.jointplot(x='ENTRIESn', y='ENTRIESn_hourly', data=entries_df, size=7, ratio=5)   # Returns JointGrid object not figure
# Read more: https://stanford.edu/~mwaskom/software/seaborn/generated/seaborn.JointGrid.html
jg.set_axis_labels(xlabel='Cumulative Entries', ylabel='Hourly Entries')

# %% [markdown]
# #### Group Data by Hours

# %%
subway_df = pd.read_csv('../data/nyc_subway_weather.csv')

# %%
grouped_entries_by_hour = subway_df.groupby('hour', as_index=False).mean()

# %%
fig = plt.figure(figsize=(14,7))

ax = sns.barplot(x='hour', y='ENTRIESn_hourly', data=grouped_entries_by_hour)
ax.xaxis.set_ticklabels(['12MN-4AM', '4AM-8AM', '8AM-12NN', '12NN-4PM', '4PM-8PM', '8PM-12MN'])
ax.tick_params(labelsize=12)
ax.set_ylabel('Average Hourly Entries', fontsize=14)
ax.set_xlabel('Hour Interval', fontsize=14)

fig.add_axes(ax)
fig.suptitle('Average Hourly Entries by Time Interval', fontsize=18)
fig.savefig(fig_prefix+'entries_by_hour_interval')

# %%
grouped_entries_by_day = subway_df.groupby(['day_week', 'rain']).mean()['ENTRIESn_hourly']
grouped_entries_by_day = grouped_entries_by_day.reset_index()

# %%
fig = plt.figure(figsize=(12,6))
ax = sns.barplot(x='day_week', y='ENTRIESn_hourly', hue='rain', data=grouped_entries_by_day)
ax.set_xticklabels(days_list)
ax.tick_params(labelsize=12)
sns.despine(left=True, bottom=True)

plt.xlabel('Day', fontsize=12)
plt.ylabel('Average Hourly Entries', fontsize=12)
plt.title('Average Hourly Entries by Day', fontsize=14)
